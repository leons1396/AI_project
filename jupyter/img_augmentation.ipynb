# %%
import os
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# Data Augmentation Techniques. Flipping, Rotation

# %%
def flip_image_and_show(img):
    # flip vertical
    img_v = cv2.flip(img, 0)
    #show_image_plt(onion_sq_v)

    #flip horizontal
    img_h = cv2.flip(img, 1)
    #show_image_plt(onion_sq_h)

    #flip vertical + horizontal
    img_vh = cv2.flip(img, -1)
    #show_image_plt(onion_sq_vh)

    fig, axarr = plt.subplots(2, 2) #1 row, 3 cols
    fig.tight_layout(h_pad=4)
    axarr[0][0].imshow(img)
    axarr[0][0].set_title("Original")
    axarr[0][1].imshow(img_v)
    axarr[0][1].set_title("Flip Vertical")
    axarr[1][0].imshow(img_h)
    axarr[1][0].set_title("Flip Horizontal")
    axarr[1][1].imshow(img_vh)
    axarr[1][1].set_title("Flip Vertical + Horizontal")
    fig.suptitle('Flipped Images')
    plt.subplots_adjust(top = 0.85)


def rotate_image_and_show(img):
    # rotate 90 degree clockwise
    img_r90 = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
    #show_image_plt(onion_sq_v)
    
    #rotate 180 degree
    img_r180 = cv2.rotate(img, cv2.ROTATE_180)
    #show_image_plt(onion_sq_h)

    #rotate 90 degree counterclockwise
    img_rcw90 = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)
    #show_image_plt(onion_sq_vh)

    fig, axarr = plt.subplots(2, 2) #2 row, 2 cols
    fig.tight_layout(h_pad=4)

    axarr[0][0].imshow(img)
    axarr[0][0].set_title("Original")
    axarr[0][1].imshow(img_r90)
    axarr[0][1].set_title("+ 90")
    axarr[1][0].imshow(img_r180)
    axarr[1][0].set_title("+ 180")
    axarr[1][1].imshow(img_rcw90)
    axarr[1][1].set_title("- 90")

    fig.suptitle('Rotated Images')
    plt.subplots_adjust(top = 0.85)

# %% [markdown]
# Resize Image to square format. Currently 256x256

# %%
def resize_to_square(vegi_bgr):
    img_size = 256
    height, width = vegi_bgr.shape[:2]
    a1 = width / height
    a2 = height / width

    if (a1 > a2):
        r_img = cv2.resize(vegi_bgr, (round(img_size * a1), img_size), interpolation = cv2.INTER_AREA)
        margin = int(r_img.shape[1]/6)
        resized_img = r_img[0:img_size, margin:(margin+img_size)]

    elif(a1 < a2):
        # if height greater than width
        r_img = cv2.resize(vegi_bgr, (img_size, round(img_size * a2)), interpolation = cv2.INTER_AREA)
        margin = int(r_img.shape[0]/6)
        resized_img = r_img[margin:(margin+img_size), 0:img_size]

    elif(a1 == a2):
        # if height and width are equal
        r_img = cv2.resize(vegi_bgr, (img_size, round(img_size * a2)), interpolation = cv2.INTER_AREA)
        resized_img = r_img[0:img_size, 0:img_size]

    if(resized_img.shape[0] != img_size or resized_img.shape[1] != img_size):
        resized_img = r_img[0:img_size, 0:img_size]

    return resized_img

# %%
folders = ["Zwiebel_Trieb"]
path = []
# Read from C:
for fold in folders:
    for fname in os.listdir(f"D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/{fold}"):
        path.append(f"D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/{fold}/{fname}")

# %%
#split path
path
# Out:
# ['D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_1.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_10.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_100.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_101.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_102.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_103.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_104.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_105.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_106.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_107.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_108.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_109.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_11.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_110.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_111.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_112.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_113.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_114.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_115.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_116.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_117.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_118.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_119.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_12.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_120.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_121.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_122.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_123.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_124.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_125.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_126.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_127.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_128.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_129.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_13.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_130.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_131.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_132.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_133.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_136.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_137.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_138.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_139.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_14.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_140.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_141.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_142.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_143.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_144.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_145.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_146.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_147.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_149.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_15.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_150.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_151.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_152.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_153.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_154.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_155.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_156.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_157.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_158.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_159.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_16.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_160.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_162.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_163.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_164.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_165.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_166.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_167.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_168.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_169.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_17.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_170.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_171.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_172.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_173.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_175.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_176.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_177.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_178.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_179.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_18.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_180.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_181.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_182.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_183.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_184.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_185.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_186.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_19.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_191.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_192.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_193.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_194.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_195.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_196.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_197.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_198.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_199.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_2.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_20.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_204.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_205.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_206.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_207.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_208.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_209.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_21.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_210.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_211.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_22.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_23.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_24.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_25.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_26.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_27.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_28.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_29.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_3.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_30.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_31.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_32.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_33.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_34.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_35.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_37.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_38.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_39.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_4.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_40.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_41.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_42.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_43.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_44.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_45.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_46.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_47.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_48.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_49.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_50.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_51.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_52.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_53.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_54.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_55.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_57.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_58.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_59.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_6.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_60.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_61.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_62.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_63.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_64.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_65.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_66.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_67.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_68.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_69.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_7.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_70.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_71.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_73.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_74.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_75.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_76.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_77.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_78.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_79.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_8.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_80.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_81.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_82.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_83.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_84.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_85.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_86.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_87.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_88.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_89.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_90.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_91.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_92.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_93.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_94.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_95.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_96.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_97.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_98.jpg',
#  'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/Zwiebel_Trieb/zwiebel_trieb_99.jpg']

# %%
j = 1
for i, path in enumerate(path):
    #print(f"++++++++++++++++++++NEW IMAGE +++++++++++++++++++++++\n")
    #print(path)
    if 'desktop.ini' in path:
        continue
    vegi_label = "Zwiebel_Trieb" #should be the folder name
 
    vegi_BGR = cv2.imread(path) # As BGR
    vegi_sq_BGR_original = resize_to_square(vegi_BGR) # BGR
    vegi_sq_RGB = cv2.cvtColor(vegi_sq_BGR_original, cv2.COLOR_BGR2RGB)
    cv2.imwrite(f"D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data_augumentation/{vegi_label}/{vegi_label.lower()}_{j}.jpg", cv2.cvtColor(vegi_sq_RGB, cv2.COLOR_BGR2RGB))
    j += 1
    # Horizontal Flip orig
    vegi_sq_RGB_original_v = cv2.flip(vegi_sq_RGB, 1)
    cv2.imwrite(f"D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data_augumentation/{vegi_label}/{vegi_label.lower()}_{j}.jpg", cv2.cvtColor(vegi_sq_RGB_original_v, cv2.COLOR_BGR2RGB))
    j += 1
    # Rotate orig 90 clockwise
    vegi_sq_RGB_rotate = cv2.rotate(vegi_sq_RGB, cv2.ROTATE_90_CLOCKWISE)
    cv2.imwrite(f"D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data_augumentation/{vegi_label}/{vegi_label.lower()}_{j}.jpg", cv2.cvtColor(vegi_sq_RGB_rotate, cv2.COLOR_BGR2RGB))
    j += 1
    # Horizontal Flip of rotated 90 clockwise
    vegi_sq_RGB_original_v_2 = cv2.flip(vegi_sq_RGB_rotate, 1)
    cv2.imwrite(f"D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data_augumentation/{vegi_label}/{vegi_label.lower()}_{j}.jpg", cv2.cvtColor(vegi_sq_RGB_original_v_2, cv2.COLOR_BGR2RGB))
    j += 1
    #
    vegi_sq_RGB_rotate_2 = cv2.rotate(vegi_sq_RGB_rotate, cv2.ROTATE_90_CLOCKWISE)
    cv2.imwrite(f"D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data_augumentation/{vegi_label}/{vegi_label.lower()}_{i}.jpg", cv2.cvtColor(vegi_sq_RGB_rotate_2, cv2.COLOR_BGR2RGB))
    j += 1

    vegi_sq_RGB_original_v_3 = cv2.flip(vegi_sq_RGB_rotate_2, 1)
    cv2.imwrite(f"D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data_augumentation/{vegi_label}/{vegi_label.lower()}_{i}.jpg", cv2.cvtColor(vegi_sq_RGB_original_v_3, cv2.COLOR_BGR2RGB))
    j += 1
