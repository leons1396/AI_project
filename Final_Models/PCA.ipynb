# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
from matplotlib import colors
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd
import seaborn as sns

import mpl_toolkits.mplot3d

# %%
#import data
data= pd.read_csv("D:\Dokumente\Master-Studium\Semester3\KI_Projekt\egis_all.csv")
data=data.drop(columns=["Unnamed: 0","green pixels"])
data.loc[data["Label"]=="Karotte","Label"]=0
data.loc[data["Label"]=="Kartoffel","Label"]=1
data.loc[data["Label"]=="Zwiebel","Label"]=2
data.loc[data["Label"]=="Karotte_Trieb","Label"]=3
data.loc[data["Label"]=="Kartoffel_Trieb","Label"]=4
data.loc[data["Label"]=="Zwiebel_Trieb","Label"]=5

data["Label"]=data["Label"].astype("int")

X=data.iloc[:,0:10]
y=data.iloc[:,10]
y.shape
# Out:
# (6514,)

# %%
scaler = StandardScaler()

pca=PCA(n_components=5)
pca.fit(X)
# Out:
# PCA(n_components=5)

# %%
X_new=pca.transform(X)
print(X_new)
# Out:
# [[-1250.33189563    36.90423557   -10.77752466    24.41928792
#     -30.64402286]
#  [-1250.32759877    37.77196029   -12.93278769    20.83340733
#     -34.00519057]
#  [-1250.53411131    36.49742199   -19.0883991     21.91286168
#     -33.25755914]
#  ...
#  [-1251.47136292   -69.91485366    28.79501817    -4.50461905
#     -16.84398416]
#  [-1251.50968734   -63.4654125     21.37400707    -5.04367024
#     -13.98615678]
#  [-1251.47187908   -70.37383228    28.76951916    -5.59713817
#     -16.17631524]]

# %%
new_data=pd.DataFrame(X_new, y)
new_data.head()
# Out:
#                  0          1          2          3          4
# Label
# 1     -1250.331896  36.904236 -10.777525  24.419288 -30.644023
# 1     -1250.327599  37.771960 -12.932788  20.833407 -34.005191
# 1     -1250.534111  36.497422 -19.088399  21.912862 -33.257559
# 1     -1251.023028  -1.827908  -5.401358  17.059577 -41.754801
# 1     -1250.857704   8.141778  -9.036995  14.874865 -39.683366

# %%
fig = plt.figure(1, figsize=(10,10))
plt.clf()

ax = fig.add_subplot(111, projection="3d", elev=48, azim=134)
ax.set_position([0, 0, 0.95, 1])






ax.scatter(X_new[:, 4], X_new[:, 3], X_new[:, 2], c=y, cmap=plt.cm.nipy_spectral, edgecolor="k")

ax.xaxis.set_ticklabels([])
ax.yaxis.set_ticklabels([])
ax.zaxis.set_ticklabels([])

plt.show()
