# %% [markdown]
# CNN Modell wird hier aufgebaut und auf Bilder mit 128x128 angewandt

# %%
import os
import tensorflow as tf 
from tensorflow import keras 
from keras.regularizers import L2

import matplotlib.pyplot as plt
import numpy as np

# %%
img_height = 128
img_width =128
batch_size=32

# %%
#import train Dataset with seperate validation Dataset

ds_train=tf.keras.preprocessing.image_dataset_from_directory(
    'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/',
    labels='inferred',
    label_mode='int',
    color_mode='rgb',
    batch_size=batch_size,
    image_size=(img_height, img_width),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset='training'
)

ds_val=tf.keras.preprocessing.image_dataset_from_directory(
    'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN_Data/',
    labels='inferred',
    label_mode='int',
    color_mode='rgb',
    batch_size=batch_size,
    image_size=(img_height, img_width),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset='validation'
)
# Out:
# Found 2156 files belonging to 6 classes.
# Using 1725 files for training.
# Found 2156 files belonging to 6 classes.
# Using 431 files for validation.

# %%
#Klassennamen ausgeben und speichenr
class_names=ds_train.class_names
print(class_names)
# Out:
# ['Karotte', 'Karotte_Trieb', 'Kartoffel', 'Kartoffel_Trieb', 'Zwiebel', 'Zwiebel_Trieb']

# %%
#Bilder einfach mal ausgeben lassen
plt.figure(figsize=(10, 10))
for images, labels in ds_train.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
#batch und Bildgrößen ausgeben lassen
for image_batch, labels_batch in ds_train:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 128, 128, 3)
# (32,)

# %%
#Modell definieren 2 Conv2D layer und am ende ein voll vernetztes 
model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(filters=16,kernel_size=3, activation='relu',padding='same', kernel_regularizer=L2(0.01),input_shape=[img_height,img_width, 3]),
  tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
  tf.keras.layers.Conv2D(filters=32,kernel_size=3, activation='relu',padding='same', kernel_regularizer=L2(0.01)),
  tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(6, activation='softmax')
])

# %%
#Modell Kompilieren
model.compile(
  optimizer='adam',
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
#Modell trainieren
epoch=40
history=model.fit(
  ds_train,
  validation_data=ds_val,
  epochs=epoch
)
# Out:
# Epoch 1/40
# C:\Users\Lennart Pc\AppData\Roaming\Python\Python310\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 54/54 [==============================] - 13s 234ms/step - loss: 1.9926 - accuracy: 0.2672 - val_loss: 1.6623 - val_accuracy: 0.4478
# Epoch 2/40
# 54/54 [==============================] - 13s 226ms/step - loss: 1.4923 - accuracy: 0.4817 - val_loss: 1.2139 - val_accuracy: 0.6288
# Epoch 3/40
# 54/54 [==============================] - 12s 223ms/step - loss: 1.2244 - accuracy: 0.5901 - val_loss: 1.2069 - val_accuracy: 0.5800
# Epoch 4/40
# 54/54 [==============================] - 12s 224ms/step - loss: 1.0526 - accuracy: 0.6730 - val_loss: 0.8851 - val_accuracy: 0.7657
# Epoch 5/40
# 54/54 [==============================] - 13s 227ms/step - loss: 0.9849 - accuracy: 0.6910 - val_loss: 0.8297 - val_accuracy: 0.7517
# Epoch 6/40
# 54/54 [==============================] - 12s 227ms/step - loss: 0.8488 - accuracy: 0.7391 - val_loss: 0.7625 - val_accuracy: 0.7796
# Epoch 7/40
# 54/54 [==============================] - 12s 227ms/step - loss: 0.7658 - accuracy: 0.7635 - val_loss: 0.7126 - val_accuracy: 0.7958
# Epoch 8/40
# 54/54 [==============================] - 12s 223ms/step - loss: 0.7028 - accuracy: 0.7948 - val_loss: 0.6324 - val_accuracy: 0.8260
# Epoch 9/40
# 54/54 [==============================] - 12s 223ms/step - loss: 0.6795 - accuracy: 0.7948 - val_loss: 0.6688 - val_accuracy: 0.7912
# Epoch 10/40
# 54/54 [==============================] - 12s 226ms/step - loss: 0.6478 - accuracy: 0.7983 - val_loss: 0.6219 - val_accuracy: 0.8097
# Epoch 11/40
# 54/54 [==============================] - 12s 226ms/step - loss: 0.5653 - accuracy: 0.8319 - val_loss: 0.5762 - val_accuracy: 0.8213
# Epoch 12/40
# 54/54 [==============================] - 12s 224ms/step - loss: 0.5415 - accuracy: 0.8412 - val_loss: 0.5341 - val_accuracy: 0.8422
# Epoch 13/40
# 54/54 [==============================] - 12s 224ms/step - loss: 0.4954 - accuracy: 0.8603 - val_loss: 0.5249 - val_accuracy: 0.8631
# Epoch 14/40
# 54/54 [==============================] - 13s 229ms/step - loss: 0.5039 - accuracy: 0.8626 - val_loss: 0.5602 - val_accuracy: 0.8376
# Epoch 15/40
# 54/54 [==============================] - 12s 223ms/step - loss: 0.4386 - accuracy: 0.8835 - val_loss: 0.5830 - val_accuracy: 0.8306
# Epoch 16/40
# 54/54 [==============================] - 13s 226ms/step - loss: 0.4545 - accuracy: 0.8783 - val_loss: 0.5481 - val_accuracy: 0.8353
# Epoch 17/40
# 54/54 [==============================] - 12s 224ms/step - loss: 0.4171 - accuracy: 0.8899 - val_loss: 0.5296 - val_accuracy: 0.8399
# Epoch 18/40
# 54/54 [==============================] - 12s 224ms/step - loss: 0.3848 - accuracy: 0.9043 - val_loss: 0.5194 - val_accuracy: 0.8515
# Epoch 19/40
# 54/54 [==============================] - 12s 224ms/step - loss: 0.3644 - accuracy: 0.9154 - val_loss: 0.5020 - val_accuracy: 0.8608
# Epoch 20/40
# 54/54 [==============================] - 13s 226ms/step - loss: 0.3498 - accuracy: 0.9090 - val_loss: 0.5115 - val_accuracy: 0.8608
# Epoch 21/40
# 54/54 [==============================] - 13s 233ms/step - loss: 0.3563 - accuracy: 0.9101 - val_loss: 0.5022 - val_accuracy: 0.8538
# Epoch 22/40
# 54/54 [==============================] - 13s 234ms/step - loss: 0.3415 - accuracy: 0.9142 - val_loss: 0.4775 - val_accuracy: 0.8608
# Epoch 23/40
# 54/54 [==============================] - 13s 232ms/step - loss: 0.3176 - accuracy: 0.9206 - val_loss: 0.4716 - val_accuracy: 0.8677
# Epoch 24/40
# 54/54 [==============================] - 13s 228ms/step - loss: 0.3191 - accuracy: 0.9200 - val_loss: 0.4736 - val_accuracy: 0.8631
# Epoch 25/40
# 54/54 [==============================] - 13s 228ms/step - loss: 0.3203 - accuracy: 0.9113 - val_loss: 0.5069 - val_accuracy: 0.8608
# Epoch 26/40
# 54/54 [==============================] - 13s 233ms/step - loss: 0.3173 - accuracy: 0.9287 - val_loss: 0.4873 - val_accuracy: 0.8701
# Epoch 27/40
# 54/54 [==============================] - 12s 226ms/step - loss: 0.2866 - accuracy: 0.9293 - val_loss: 0.4536 - val_accuracy: 0.8794
# Epoch 28/40
# 54/54 [==============================] - 13s 228ms/step - loss: 0.2760 - accuracy: 0.9322 - val_loss: 0.5095 - val_accuracy: 0.8561
# Epoch 29/40
# 54/54 [==============================] - 12s 225ms/step - loss: 0.2927 - accuracy: 0.9322 - val_loss: 0.5138 - val_accuracy: 0.8608
# Epoch 30/40
# 54/54 [==============================] - 13s 227ms/step - loss: 0.2759 - accuracy: 0.9351 - val_loss: 0.4834 - val_accuracy: 0.8701
# Epoch 31/40
# 54/54 [==============================] - 13s 228ms/step - loss: 0.2983 - accuracy: 0.9235 - val_loss: 0.5259 - val_accuracy: 0.8538
# Epoch 32/40
# 54/54 [==============================] - 12s 226ms/step - loss: 0.2585 - accuracy: 0.9432 - val_loss: 0.5184 - val_accuracy: 0.8724
# Epoch 33/40
# 54/54 [==============================] - 12s 226ms/step - loss: 0.2415 - accuracy: 0.9432 - val_loss: 0.4878 - val_accuracy: 0.8747
# Epoch 34/40
# 54/54 [==============================] - 13s 231ms/step - loss: 0.2624 - accuracy: 0.9322 - val_loss: 0.4940 - val_accuracy: 0.8585
# Epoch 35/40
# 54/54 [==============================] - 13s 227ms/step - loss: 0.2362 - accuracy: 0.9449 - val_loss: 0.5212 - val_accuracy: 0.8631
# Epoch 36/40
# 54/54 [==============================] - 12s 226ms/step - loss: 0.2170 - accuracy: 0.9583 - val_loss: 0.5123 - val_accuracy: 0.8608
# Epoch 37/40
# 54/54 [==============================] - 12s 225ms/step - loss: 0.2405 - accuracy: 0.9438 - val_loss: 0.5071 - val_accuracy: 0.8770
# Epoch 38/40
# 54/54 [==============================] - 13s 226ms/step - loss: 0.2160 - accuracy: 0.9530 - val_loss: 0.5143 - val_accuracy: 0.8724
# Epoch 39/40
# 54/54 [==============================] - 12s 225ms/step - loss: 0.2155 - accuracy: 0.9571 - val_loss: 0.6434 - val_accuracy: 0.8445
# Epoch 40/40
# 54/54 [==============================] - 12s 225ms/step - loss: 0.2648 - accuracy: 0.9316 - val_loss: 0.5261 - val_accuracy: 0.8677

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 128)               4194432
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 4,200,294
# Trainable params: 4,200,294
# Non-trainable params: 0
# _________________________________________________________________

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epoch)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
ds_test=tf.keras.utils.image_dataset_from_directory(
    'D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN/Test_set/',
    color_mode='rgb',
    labels='inferred',
    batch_size=batch_size,
    image_size=(img_height, img_width),
    shuffle=True,   
)
# Out:
# Found 339 files belonging to 6 classes.

# %%
result=model.evaluate(ds_test)
# Out:
# 11/11 [==============================] - 4s 101ms/step - loss: 2.0289 - accuracy: 0.7257

# %%
test=tf.keras.utils.load_img('D:/Dokumente/Master-Studium/Semester3/test.jpg', target_size=(img_height, img_width))
test_array = tf.keras.utils.img_to_array(test)
test_array = tf.expand_dims(test_array, 0)

# %%
predictions = model.predict(test_array)
score = tf.nn.softmax(predictions[0])
print(predictions)
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 116ms/step
# [[6.4876898e-05 7.4726081e-10 1.7011220e-07 3.3167310e-12 9.9993479e-01
#   1.6412459e-07]]
# This image most likely belongs to Zwiebel with a 35.22 percent confidence.

# %%
model.save('D:/Dokumente/Master-Studium/Semester3/KI_Projekt/CNN/model.keras')
